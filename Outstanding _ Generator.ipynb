# %%
import pandas as pd
import numpy as np
All_Students_Results = pd.read_csv('C:\\Users\\USER\\Desktop\\NOUN\\DCS\\2021_2 RESULT\\Computer Science 2021_2\\B.Sc. Computer Science\\B.Sc. Computer Science -- Comprehensive Results.csv')
len(All_Students_Results)
Computer_Science_Registrables = {'GST101' , 'GST103' , 'GST107' , 'BIO101' , 'MTH101' , 'MTH103' , 'CIT191' , 'CHM101' ,'CHM191','PHY101','PHY191','BIO191','MTH211','GST102','GST104','CIT104','MTH102','CIT108','PHY102','PHY103','GST201','GST203','CIT211','CIT215','CIT217','MTH281','PHY308','CIT213','GST202','GST204','CIT206','CIT210','CIT216','CIT237','CIT212','CIT292','MTH212','STT211','PHY202','CIT309','CIT301','CIT335','CIT315','CIT383','CIT389','CIT353','CIT333','CIT310','CIT314','CIT304','CIT316','GST302','CIT332','CIT308','CIT398','CIT401','CIT403','CIT421','CIT423','CIT427','CIT411','CIT435','CIT410','CIT478','CIT474','CIT432','CIT499','CIT412','CIT484'}
Computer_Science_Registrables
All_Students_Results
# Out:
#       Matric Number                        Name  \
# 0      NOU017035674  ANYIGOR Francis Chukwudike
# 1      NOU040001879   KOMOLAFE Olutayo Emmanuel
# 2      NOU040002083    ADEWOYIN Abraham Adewale
# 3      NOU040002151        YUSUF Atilola Alimat
# 4      NOU040002263    SORETIRE Ayodeji Francis
# ...             ...                         ...
# 44197  NOU213197490  EMOGA Ogagaoghene Emmanuel
# 44198  NOU213197831        SEKEGOR PEACE UFUOMA
# 44199  NOU213197969           ABUBAKAR Mustapha
# 44200  NOU213198539             IMOUDU DANIELLA
# 44201  NOU213199017   AKINWALERE SAMUEL OLADEJI
#
#                             StudyCentre Mobile Number Entry Level  TCC  TCE  \
# 0                                   NaN     706703967          DE    0    0
# 1                    Lagos Study Centre    7000000111         NaN    8    8
# 2                    Lagos Study Centre    7000000111         NaN    6    6
# 3                    Lagos Study Centre    7000000111         NaN    6    6
# ...

# %%
print(All_Students_Results.columns)
number_of_students = len(All_Students_Results)
print(number_of_students)
# Out:
# Index(['Matric Number', 'Name', 'StudyCentre', 'Mobile Number', 'Entry Level',
#        'TCC', 'TCE', 'TGPE', 'CGPA', 'Passed Courses', 'Outstanding Courses',
#        'Failed Courses'],
#       dtype='object')
# 44202

# %%
def generate_passedCourse_list(graded_course):
    passed_course_list = []
    for i in range(len(graded_course)):
        course= graded_course[i][0:6]
        passed_course_list.append(course)
    return passed_course_list

# %%
def regularize_course_codes(courses):
    
    for n in range(len(courses)):
        if courses[n] == 'CIT101':
            courses.remove('CIT101')
            courses.append('GST103')
        elif courses[n] == 'MTH133':
            courses.remove('MTH133')
            courses.append('MTH103')
        elif  courses[n] == 'MTH142':
            courses.remove('MTH142')
            courses.append('MTH103')
        elif courses[n] == 'MTH121' :
            courses.remove('MTH121')
            courses.append('MTH101')
        elif courses[n] == 'MTH131' :
            courses.remove('MTH131')
            courses.append('MTH101')
        elif courses[n] == 'MTH112' :
            courses.remove('MTH112')
            courses.append('MTH102')
        elif  courses[n] == 'MTH122':
            courses.remove('MTH122')
            courses.append('MTH102')
        elif courses[n] == 'PHY132' :
            courses[n] ='PHY102'
            courses.remove('PHY132')
            courses.append('PHY102')
        elif courses[n] == 'PHY111' :
            courses.remove('PHY111')
            courses.append('PHY101')
        elif courses[n] == 'PHY113':
            courses.remove('PHY113')
            courses.append('PHY101')
        elif courses[n] == 'GST301' :
            courses.remove('GST301')
            courses.append('GST302')
        elif courses[n] == 'CIT110':
            courses[n] = 'CIT410'
            courses.remove('CIT110')
            courses.append('CIT410')
        elif  courses[n]=='CIT208' :
            courses.remove('CIT208')
            courses.append('CIT108')
        elif courses[n] == 'MTH282' :
            courses.remove('MTH282')
            courses.append('MTH281')
        elif courses[n] == 'MTH213':
            courses.remove('MTH213')
            courses.append('MTH281')
        elif courses[n] == 'STT102' :
            courses.remove('STT102')
            courses.append('STT211')
        elif courses[n] == 'CIT143' :
            courses.remove('CIT143')
            courses.append('CIT204')
        elif courses[n] == 'CIT341' :
            courses.remove('CIT341')
            courses.append('CIT216')
        elif courses[n] == 'MTH232':
            courses.remove('MTH232')
            courses.append('CIT206')
        elif courses[n] == 'CIT311' :
            courses[n] = 'CIT423'
            courses.remove('CIT311')
            courses.append('CIT423')
        elif courses[n] == 'CIT465' :
            courses.remove('CIT465')
            courses.append('CIT423')
        elif courses[n]=='CIT351':
            courses.remove('CIT351')
            courses.append('CIT301')
        elif courses[n] == 'MTH307' or courses[n] == 'MTH381' or courses[n] == 'MTH382' :
            courses.remove('MTH307')
            courses.remove('MTH381')
            courses.remove('MTH382')
            courses.append('CIT335')
        elif courses[n] == 'CIT463' or courses[n] == 'CIT372' :
            courses.remove('CIT463')
            courses.remove('CIT372')
            courses.append('CIT315')
        elif courses[n] == 'CIT236':
            courses.remove('CIT236')
            courses.append('PHY308')
        elif courses[n] == 'CIT322' or courses[n] == 'CIT461' :
            courses.remove('CIT322')
            courses.remove('CIT461')
            courses.append('CIT421')
        elif courses[n] == 'CIT342':
            courses.remove('CIT342')
            courses.append('CIT308')
        elif courses[n] == 'CIT344':
            courses.remove('CIT344')
            courses.append('CIT310')
        elif courses[n] == 'CIT467':
            courses.remove('CIT467')
            courses.append('CIT401')                
        elif courses[n] == 'CIT445':
            courses.remove('CIT445')
            courses.append('CIT316')
        elif courses[n] == 'PHY192' :
            courses.remove('PHY192')
            courses.append('PHY103')
        elif courses[n] == 'CHM102' :
            courses.remove('CHM102')
            courses.append('PHY202')
        elif courses[n] == 'CIT102' :
            courses.remove('CIT102')
            courses.append('CIT104')
                
    return courses

# %%
def Regularize_Gst_Courses(matric_No,courses):
    print(courses)
    for n in range(len(courses)):
        if int(matric_No[3:5]) <= 15 and 'GST301' in courses or 'GST302' in courses  :
            gst_to_be_removed = courses[n]
            courses.remove(gst_to_be_removed)
            
    return courses

# %%
All_Student_Passed_Courses_list = All_Students_Results['Passed Courses'].values.tolist()
All_Student_Passed_Courses_list
# Out:
# [nan,
#  'CIT101-B,GST103-E,GST105-A,GST107-C',
#  'CIT101-D,GST105-B,GST107-C',
#  'CIT101-E,GST105-B,GST107-A',
#  'CIT101-C,GST101-E,GST105-B,GST107-D',
#  'CIT101-D,GST102-D,GST103-B,GST105-A,GST107-A,MTH133-C',
#  'CIT101-E,GST103-E,GST105-E,GST107-C',
#  'GST107-C',
#  'CIT101-E,GST101-E,GST103-E,GST105-C,GST107-C',
#  'CIT101-E,GST105-B,GST107-B',
#  'CIT101-E,GST103-E,GST105-C,GST107-E',
#  'CIT101-D,GST103-C,GST105-C,GST107-D',
#  'CIT101-C,GST103-D,GST105-E,GST107-A',
#  'CIT101-D,GST105-A,GST107-B',
#  'CIT101-E,GST103-C,GST105-B,GST107-B',
#  'CIT101-C,GST103-B,GST105-C,GST107-A',
#  'GST101-E,GST103-C,GST105-E,GST107-D',
#  'CIT101-E,GST101-D,GST103-A,GST105-B,GST107-B',
#  'GST103-E',
#  'CIT101-D,GST101-B,GST105-A,GST107-B',
#  'CIT101-E,GST103-C,GST105-B,GST107-B',
#  'CIT101-E,GST103-C,GST105-E,GST107-B',
#  'CIT101-E,GST103-C,GST105-B,GST107-B',
#  'GST103-C,GST105-D,GST107-C',
#  'CIT101-E,CIT143-D,GST105-E,MTH121-B,MTH133-C',
# ...

# %%
Outstanding_list =[]
for i in range(len(All_Students_Results)):
    if type(All_Student_Passed_Courses_list[i]) != type(All_Student_Passed_Courses_list[0]) :
        Each_Student_Passed_Courses_list= All_Student_Passed_Courses_list[i].split(',')
        Each_Student_Passed_Courses_list = generate_passedCourse_list(Each_Student_Passed_Courses_list)
        Each_Student_Passed_Courses_list = regularize_course_codes(Each_Student_Passed_Courses_list)
        Each_Student_Passed_Courses_set = set(Each_Student_Passed_Courses_list)
        Oustandings = Computer_Science_Registrables - Each_Student_Passed_Courses_set
        Outstanding_list.append(Oustandings)
        All_Students_Results['Outstanding Courses'][i] = Oustandings
# Out:
# <ipython-input-110-23d646e2f268>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   All_Students_Results['Outstanding Courses'][i] = Oustandings

# %%
All_Students_Results.to_csv('C:\\Users\\USER\\Desktop\\Book2.csv')
